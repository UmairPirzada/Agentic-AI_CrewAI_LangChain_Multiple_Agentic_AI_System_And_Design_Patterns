# %% [markdown]
# <a href="https://colab.research.google.com/github/UmairPirzada/Agentic-AI_CrewAI_LangChain_Multiple_Agentic_AI_System_And_Design_Patterns/blob/main/CrewAI_%7C_Planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# gemini-1.5-flash

# %%
! pip install -q -U crewai crewai-tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.5/548.5 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 kB 15.0 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')
os.environ['MODEL'] = "gemini/gemini-1.5-flash"
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
os.environ['MODEL']
# Out:
# 'gemini/gemini-1.5-flash'

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
! crewai create crew pr1
# Out:
# Creating folder pr1...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyBxjPDYqEUHZqT6EonM7n9Q9G_VYowGz9k
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created pr1/.gitignore
#   - Created pr1/pyproject.toml
#   - Created pr1/README.md
#   - Created pr1/knowledge/user_preference.txt
#   - Created pr1/src/pr1/__init__.py
#   - Created pr1/src/pr1/main.py
#   - Created pr1/src/pr1/crew.py
# ...

# %%
! pwd
# Out:
# /content

# %%
# %cd pr1
# Out:
# /content/pr1

# %%
# !ls
# Out:
# knowledge  pyproject.toml  README.md  src  tests

# %%
! crewai run
# Out:
# Streaming output truncated to the last 5000 lines.
# langchain  ------------------------------ 430.42 KiB/987.87 KiB
# jedi       ------------------------------ 505.98 KiB/1.50 MiB
# kubernetes ------------------------------ 1.49 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.08 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.09 MiB/2.36 MiB
# langchain-community ------------------------------ 893.69 KiB/2.41 MiB
# shapely    ------------------------------ 2.10 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.17 MiB/2.73 MiB
#    Building pr1 @ file:///content/pr1
# ⠼ Preparing packages... (112/213)
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 5.53 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 23.67 KiB/25.89 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# ...

# %%
! crewai run
# Out:
# Running the Crew
#
# [2025-03-11 06:14:23][🚀 CREW 'CREW' STARTED, A6769D10-F1F4-4446-9889-EF099FAD5EED]: 2025-03-11 06:14:23.063822
#
# [2025-03-11 06:14:23][INFO]: Planning the crew execution
#
# [2025-03-11 06:14:23][📋 TASK STARTED: BASED ON THESE TASKS SUMMARY:
#                 TASK NUMBER 1 - CONDUCT A THOROUGH RESEARCH ABOUT AI LLMS MAKE SURE YOU FIND ANY INTERESTING AND RELEVANT INFORMATION GIVEN THE CURRENT YEAR IS 2025.
#
#                 "TASK_DESCRIPTION": CONDUCT A THOROUGH RESEARCH ABOUT AI LLMS MAKE SURE YOU FIND ANY INTERESTING AND RELEVANT INFORMATION GIVEN THE CURRENT YEAR IS 2025.
#
#                 "TASK_EXPECTED_OUTPUT": A LIST WITH 10 BULLET POINTS OF THE MOST RELEVANT INFORMATION ABOUT AI LLMS
#
#                 "AGENT": AI LLMS SENIOR DATA RESEARCHER
#
#                 "AGENT_GOAL": UNCOVER CUTTING-EDGE DEVELOPMENTS IN AI LLMS
#
#                 "TASK_TOOLS": []
#                 "AGENT_TOOLS": "AGENT HAS NO TOOLS"
# ...
