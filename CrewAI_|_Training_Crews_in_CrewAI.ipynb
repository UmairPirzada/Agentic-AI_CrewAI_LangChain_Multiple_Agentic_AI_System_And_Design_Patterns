# %% [markdown]
# <a href="https://colab.research.google.com/github/UmairPirzada/Agentic-AI_CrewAI_LangChain_Multiple_Agentic_AI_System_And_Design_Patterns/blob/main/CrewAI_%7C_Training_Crews_in_CrewAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# gemini-1.5-flash

# %%
! pip install -q -U crewai crewai-tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.5/548.5 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 kB 13.0 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')
os.environ['MODEL'] = "gemini/gemini-1.5-flash"
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
os.environ['MODEL']
# Out:
# 'gemini/gemini-1.5-flash'

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
! crewai create crew pr1
# Out:
# Creating folder pr1...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyBxjPDYqEUHZqT6EonM7n9Q9G_VYowGz9k
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created pr1/.gitignore
#   - Created pr1/pyproject.toml
#   - Created pr1/README.md
#   - Created pr1/knowledge/user_preference.txt
#   - Created pr1/src/pr1/__init__.py
#   - Created pr1/src/pr1/main.py
#   - Created pr1/src/pr1/crew.py
# ...

# %%
! pwd
# Out:
# /content

# %%
# %cd pr1
# Out:
# /content/pr1

# %%
# !ls
# Out:
# knowledge  pyproject.toml  README.md  src  tests

# %%
! crewai train -n 2 -f "my_crew.pkl"
# Out:
# Training the Crew for 2 iterations
#
# [2025-03-11 09:04:48][📋 CREW 'CREW' STARTED TRAIN]: 2025-03-11 09:04:48.446771
#
# [2025-03-11 09:04:48][🚀 CREW 'CREW' STARTED, 7161110D-3E11-4AE8-828C-60346EBBE580]: 2025-03-11 09:04:48.451447
#
# [2025-03-11 09:04:48][📋 TASK STARTED: CONDUCT A THOROUGH RESEARCH ABOUT AI LLMS MAKE SURE YOU FIND ANY INTERESTING AND RELEVANT INFORMATION GIVEN THE CURRENT YEAR IS 2025.
# ]: 2025-03-11 09:04:48.469842
#
# [2025-03-11 09:04:48][🤖 AGENT 'AI LLMS SENIOR DATA RESEARCHER
# ' STARTED TASK]: 2025-03-11 09:04:48.470950
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2025.
#
#
# [2025-03-11 09:04:48][🤖 LLM CALL STARTED]: 2025-03-11 09:04:48.471164
#
# [2025-03-11 09:04:54][✅ LLM CALL COMPLETED]: 2025-03-11 09:04:54.237267
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# ...
